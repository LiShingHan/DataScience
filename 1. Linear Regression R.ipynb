# %% [markdown]
# # Linear Regression

# %%
install.packages('ggplot2')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
case75 <- read.csv("https://raw.githubusercontent.com/LiShingHan/DataScience/main/DataSet/p7.5.csv")

# %%
case75
# Out:
#    price  area
# 1  229500 1850
# 2  273300 2190
# 3  247000 2100
# 4  195100 1930
# 5  261000 2300
# 6  179700 1710
# 7  168500 1550
# 8  234400 1920
# 9  168800 1840
# 10 180400 1720
# 11 156200 1660
# 12 288350 2405
# 13 186750 1525
# 14 202100 2030
# 15 256800 2240

# %%
library(ggplot2)

# %%
ggplot(data=case75) +               # 準備畫布
    geom_point(aes(x=price,         # 散布圖
                   y=area )) +      # 把不同品種的資料標上顏色
                   theme_bw()
# Out:
# plot without title

# %%
reg = lm( price ~ area, data=case75)

# %%
reg
# Out:
# Call:
# lm(formula = price ~ area, data = case75)
#
# Coefficients:
# (Intercept)         area
#    -54191.2        139.5

# %%
plot(price ~ area, data=case75)  + abline(reg)
# Out:
# integer(0)
# plot without title
