# %% [markdown]
# # Social Network

# %%
install.packages("igraph")
library(igraph)
# Out:
# package 'igraph' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\shli\AppData\Local\Temp\RtmpIdF5Sr\downloaded_packages
# Warning message:
# "package 'igraph' was built under R version 3.6.3"
# Attaching package: 'igraph'
#
# The following objects are masked from 'package:stats':
#
#     decompose, spectrum
#
# The following object is masked from 'package:base':
#
#     union

# %%
purhead<- read.csv("C:/Rdata/purhead.csv")

# %%
head(purhead)
# Out:
#   PurID  ISFinal EmpID EmpName SupID SupName PurDate   DeliverDate Freight
# 1 Pur001 C       E01   王大明  S01   一號店  2000/1/3  2000/1/13   490
# 2 Pur002 C       E01   王大明  S04   四號店  2000/1/10 2000/1/13   340
# 3 Pur003 C       E01   王大明  S05   第五店  2000/1/13 2000/1/27   110
# 4 Pur004 C       E03   王大華  S03   第三店  2000/1/14 2000/1/21   100
# 5 Pur005 C       E10   黑黑黑  S06   幽靈店  2000/1/15 2000/1/15    50
# 6 Pur006 C       E08   張大南  S05   第五店  2000/1/20 2000/2/3    346
#   AP
# 1 21038
# 2  8819
# 3 21149
# 4 10350
# 5 24727
# 6  4445

# %%
newframe<-data.frame(purhead$EmpID,purhead$SupID)

# %%
netgraph<-graph.data.frame(newframe, directed = FALSE)
netgraph
# Out:
# IGRAPH cc0bc73 UN-- 16 120 --
# + attr: name (v/c)
# + edges from cc0bc73 (vertex names):
#  [1] E01--S01 E01--S04 E01--S05 E03--S03 E10--S06 E08--S05 E02--S04 E01--S02
#  [9] E09--S03 E01--S04 E03--S03 E07--S04 E01--S03 E10--S06 E02--S03 E05--S01
# [17] E01--S05 E07--S04 E04--S02 E01--S04 E06--S01 E04--S04 E02--S02 E01--S04
# [25] E03--S05 E07--S05 E10--S06 E01--S04 E04--S02 E09--S03 E05--S04 E08--S01
# [33] E01--S04 E05--S03 E07--S04 E01--S01 E03--S05 E07--S03 E04--S02 E02--S04
# [41] E08--S01 E06--S01 E09--S01 E01--S05 E09--S02 E10--S06 E06--S01 E08--S04
# [49] E01--S01 E09--S02 E08--S05 E04--S01 E01--S01 E10--S06 E04--S03 E06--S01
# [57] E01--S05 E03--S01 E02--S02 E08--S01 E09--S05 E03--S05 E05--S02 E01--S04
# + ... omitted several edges

# %%
plot(netgraph, layout=layout.fruchterman.reingold)
# Out:
# Plot with title ""

# %%
plot(netgraph,layout=layout.circle)
# Out:
# Plot with title ""
